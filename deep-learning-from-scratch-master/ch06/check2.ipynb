# %% [markdown]
# # 0.

# %%
import sys, os
sys.path.append(os.pardir)

import random
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist

import numpy as np
from collections import OrderedDict

from common.optimizer import *
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer
from common.util import shuffle_dataset

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)
plt.imshow(x_train[random.randint(0, x_train.shape[0])].reshape(28, 28))
plt.show()

# %% [markdown]
# # 1.

# %%
def f(x, y):
    return x**2 / 20.0 + y**2

def df(x, y):
    return x / 10.0, 2.0*y

# %%
init_pos = (7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0

# %%
optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.7)
optimizers["Momentum"] = Momentum(lr=0.05)
optimizers["AdaGrad"] = AdaGrad(lr=0.75)
optimizers["Adam"] = Adam(lr=0.5)
optimizers["RMSprop"] = RMSprop(lr = 0.1)

# %%
idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]
    
    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])
        
        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)
    
    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)
    
    X, Y = np.meshgrid(x, y) 
    Z = f(X, Y)
    
    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0
    
    # 그래프 그리기
    plt.subplot(3, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    #colorbar()
    #spring()
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")
    
plt.show()

# %% [markdown]
# # 2.

# %%
# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000

# %%
optimizers = {}
optimizers['SGD'] = SGD(lr=0.02)
optimizers['Momentum'] = Momentum(lr=0.02)
optimizers['AdaGrad'] = AdaGrad(lr=0.02)
optimizers['Adam'] = Adam(lr=0.002)
optimizers['RMSprop'] = RMSprop(lr=0.02)

# %%
networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []

# %%
# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))
# Out:
# ===========iteration:0===========
# SGD:2.2406677153321626
# Momentum:2.2794026411109187
# AdaGrad:5.534595390794653
# Adam:1.965260156230674
# RMSprop:14.858869420414699
# ===========iteration:100===========
# SGD:0.7238180378168515
# Momentum:0.5736206406483169
# AdaGrad:0.4851911917012981
# Adam:0.49752702129072024
# RMSprop:0.9887959516660946
# ===========iteration:200===========
# SGD:0.5437356402883252
# Momentum:0.44336782015509907
# AdaGrad:0.4143826463509862
# Adam:0.3952633545721591
# RMSprop:0.7053410926750814
# ===========iteration:300===========
# SGD:0.47417723746414997
# Momentum:0.3885525894905425
# AdaGrad:0.33082446605498184
# Adam:0.3198651574304062
# RMSprop:1.0021978158264884
# ===========iteration:400===========
# SGD:0.500133810375484
# Momentum:0.34005661615634614
# AdaGrad:0.31238041062676025
# Adam:0.33405413989689126
# RMSprop:0.5571734867376801
# ===========iteration:500===========
# SGD:0.4527306875206057
# Momentum:0.39140507926450796
# AdaGrad:0.2939708732916356
# Adam:0.3598772242769276
# RMSprop:0.5219432733871239
# ===========iteration:600===========
# SGD:0.6265693156700143
# Momentum:0.47858484359761866
# AdaGrad:0.42883678472296427
# Adam:0.4061641862073585
# RMSprop:1.2718855931944626
# ===========iteration:700===========
# SGD:0.3379887618822338
# Momentum:0.3119659585671738
# AdaGrad:0.2174059400227562
# Adam:0.23368170550207423
# RMSprop:0.6873418268010424
# ===========iteration:800===========
# SGD:0.3863866976105984
# Momentum:0.27776746194864826
# AdaGrad:0.2523228777334578
# Adam:0.2599139982970474
# RMSprop:0.5514984610557956
# ===========iteration:900===========
# SGD:0.37306590987455207
# Momentum:0.3117760271479251
# AdaGrad:0.24024758013815256
# Adam:0.2605096777937031
# RMSprop:0.6454367393907201
# ===========iteration:1000===========
# SGD:0.4326407128308788
# Momentum:0.3764439948475409
# AdaGrad:0.3164888712419327
# Adam:0.32710799195198126
# RMSprop:0.6703008560981225
# ===========iteration:1100===========
# SGD:0.4577876808717787
# Momentum:0.43053933335571737
# AdaGrad:0.3519341626779733
# Adam:0.3777664253129389
# RMSprop:1.1280686257549024
# ===========iteration:1200===========
# SGD:0.38199651420517056
# Momentum:0.38095010227106724
# AdaGrad:0.3366051712837485
# Adam:0.3801730896206708
# RMSprop:0.7232892080685396
# ===========iteration:1300===========
# SGD:0.3554345625995218
# Momentum:0.31197380263203767
# AdaGrad:0.27062643945851317
# Adam:0.3044936325279185
# RMSprop:1.3450164238807556
# ===========iteration:1400===========
# SGD:0.2931563494999536
# Momentum:0.2582276156594674
# AdaGrad:0.1907831778010655
# Adam:0.24225482615283345
# RMSprop:0.8746639459518888
# ===========iteration:1500===========
# SGD:0.3362303373788983
# Momentum:0.3769497413088112
# AdaGrad:0.22855679210373764
# Adam:0.3936007194362927
# RMSprop:0.856390006879832
# ===========iteration:1600===========
# SGD:0.3962277385680085
# Momentum:0.346950895961866
# AdaGrad:0.2826255966056288
# Adam:0.2987885830104966
# RMSprop:0.6507762203608618
# ===========iteration:1700===========
# SGD:0.26117452714556816
# Momentum:0.22483478449440158
# AdaGrad:0.17151688350296423
# Adam:0.23144204093627774
# RMSprop:0.81587690648918
# ===========iteration:1800===========
# SGD:0.4133846356108113
# Momentum:0.4037716638499823
# AdaGrad:0.35913476266715794
# Adam:0.33398812545808443
# RMSprop:0.6182994747764725
# ===========iteration:1900===========
# SGD:0.4582666087246756
# Momentum:0.41688320158049297
# AdaGrad:0.29372237173782273
# Adam:0.40204554204405923
# RMSprop:0.6607795491351676

# %%
# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D", "RMSprop": "v"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# # 3.

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def ReLU(x):
    return np.maximum(0, x)
def tanh(x):
    return np.tanh(x)

# %%
input_data = np.random.randn(1000, 100)  # 1000개의 데이터
node_num = 100  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5  # 은닉층이 5개
activations = {}  # 이곳에 활성화 결과를 저장

# %%
x = input_data

# %%
for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 초깃값을 다양하게 바꿔가며 실험해보자！
    # w = np.random.randn(node_num, node_num) * 1
    # w = np.random.randn(node_num, node_num) * 0.01
    w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    # w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)

    a = np.dot(x, w)

    # 활성화 함수도 바꿔가며 실험해보자！
    # z = sigmoid(a)
    # z = ReLU(a)
    z = tanh(a)

    activations[i] = z

# 히스토그램 그리기
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %% [markdown]
# # 4.

# %%
# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000

# %%
# 1. 실험용 설정==========
weight_init_types = {'std=0.1': 0.1, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.1)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []

# %%
# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))
# Out:
# ===========iteration:0===========
# std=0.1:2.3500056800859954
# Xavier:2.2673377883365085
# He:2.1377552562908715
# ===========iteration:100===========
# std=0.1:0.6480877602675128
# Xavier:0.7384704788672856
# He:0.6216915535496909
# ===========iteration:200===========
# std=0.1:0.5947941638367923
# Xavier:0.6042550368259296
# He:0.5086791228331058
# ===========iteration:300===========
# std=0.1:0.41142767485185683
# Xavier:0.4304909775386194
# He:0.3206578080310235
# ===========iteration:400===========
# std=0.1:0.41267034442056716
# Xavier:0.39554446720295683
# He:0.37212848379110464
# ===========iteration:500===========
# std=0.1:0.26833491972631496
# Xavier:0.2970745277405864
# He:0.21863393764404387
# ===========iteration:600===========
# std=0.1:0.3821981815012563
# Xavier:0.39785295464853876
# He:0.35516094915375
# ===========iteration:700===========
# std=0.1:0.32353678553537546
# Xavier:0.3732747269219793
# He:0.3119230262699698
# ===========iteration:800===========
# std=0.1:0.44493000780765823
# Xavier:0.4405778566786773
# He:0.397665149198997
# ===========iteration:900===========
# std=0.1:0.3416704099682375
# Xavier:0.34689219148534745
# He:0.3015809925310833
# ===========iteration:1000===========
# std=0.1:0.24868236137441735
# Xavier:0.2520187555017298
# He:0.22666618845466183
# ===========iteration:1100===========
# std=0.1:0.28587321016335465
# Xavier:0.30719055347238844
# He:0.27086113273462664
# ===========iteration:1200===========
# std=0.1:0.325746461538802
# Xavier:0.3343892952321445
# He:0.3096841976035215
# ===========iteration:1300===========
# std=0.1:0.32511677768188574
# Xavier:0.310330304688648
# He:0.2865547002615339
# ===========iteration:1400===========
# std=0.1:0.23738433839541448
# Xavier:0.23565684063560316
# He:0.20664000521014156
# ===========iteration:1500===========
# std=0.1:0.31065659178232174
# Xavier:0.3172110922812756
# He:0.2883019028070919
# ===========iteration:1600===========
# std=0.1:0.339320845529393
# Xavier:0.3509045435154612
# He:0.2888023842088585
# ===========iteration:1700===========
# std=0.1:0.2780436604218409
# Xavier:0.31908039242210195
# He:0.25900003818021267
# ===========iteration:1800===========
# std=0.1:0.3321012010087795
# Xavier:0.3270492609591507
# He:0.3181814274560071
# ===========iteration:1900===========
# std=0.1:0.25620294804019983
# Xavier:0.2704705301378596
# He:0.20926850013724096

# %%
# 3. 그래프 그리기==========
markers = {'std=0.1': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()

# %% [markdown]
# # 5.

# %%
# 데이터 읽기
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100], output_size=10,
                              use_batchnorm=True)

x_batch = x_train[:1]
t_batch = t_train[:1]

# %%
grad_backprop = network.gradient(x_batch, t_batch)
grad_numerical = network.numerical_gradient(x_batch, t_batch)


for key in grad_numerical.keys():
    diff = np.average( np.abs(grad_backprop[key] - grad_numerical[key]) )
    print(key + ":" + str(diff))
# Out:
# W1:0.0
# b1:0.0
# gamma1:0.0
# beta1:0.0
# W2:0.0
# b2:0.0
# gamma2:0.0
# beta2:0.055812000626165315
# W3:0.0
# b3:1.7990380059285105e-07

# %% [markdown]
# # 6.

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 학습 데이터를 줄임
x_train = x_train[:1000]
t_train = t_train[:1000]

# %%
max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01

# %%
def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list

# %%
# 그래프 그리기==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
 
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.107 - 0.089
# ..\common\multi_layer_net_extend.py:104: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ..\common\multi_layer_net_extend.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# epoch:1 | 0.107 - 0.144
# epoch:2 | 0.107 - 0.17
# epoch:3 | 0.107 - 0.228
# epoch:4 | 0.107 - 0.249
# epoch:5 | 0.107 - 0.286
# epoch:6 | 0.107 - 0.307
# epoch:7 | 0.107 - 0.331
# epoch:8 | 0.107 - 0.355
# epoch:9 | 0.107 - 0.371
# epoch:10 | 0.107 - 0.389
# epoch:11 | 0.107 - 0.414
# epoch:12 | 0.107 - 0.447
# epoch:13 | 0.107 - 0.455
# epoch:14 | 0.107 - 0.469
# epoch:15 | 0.107 - 0.49
# epoch:16 | 0.107 - 0.508
# epoch:17 | 0.107 - 0.515
# epoch:18 | 0.107 - 0.532
# No handles with labels found to put in legend.
# epoch:19 | 0.107 - 0.544
# ============== 2/16 ==============
# epoch:0 | 0.092 - 0.098
# epoch:1 | 0.107 - 0.087
# ..\common\functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# epoch:2 | 0.107 - 0.129
# epoch:3 | 0.107 - 0.178
# epoch:4 | 0.107 - 0.227
# epoch:5 | 0.107 - 0.263
# epoch:6 | 0.107 - 0.307
# epoch:7 | 0.107 - 0.352
# epoch:8 | 0.107 - 0.388
# epoch:9 | 0.107 - 0.42
# epoch:10 | 0.107 - 0.445
# epoch:11 | 0.107 - 0.472
# epoch:12 | 0.107 - 0.481
# epoch:13 | 0.107 - 0.502
# epoch:14 | 0.107 - 0.519
# epoch:15 | 0.107 - 0.53
# epoch:16 | 0.107 - 0.547
# epoch:17 | 0.107 - 0.562
# No handles with labels found to put in legend.
# epoch:18 | 0.107 - 0.581
# epoch:19 | 0.107 - 0.588
# ============== 3/16 ==============
# epoch:0 | 0.102 - 0.102
# epoch:1 | 0.308 - 0.153
# epoch:2 | 0.47 - 0.22
# epoch:3 | 0.57 - 0.277
# epoch:4 | 0.592 - 0.338
# epoch:5 | 0.645 - 0.401
# epoch:6 | 0.657 - 0.444
# epoch:7 | 0.703 - 0.492
# epoch:8 | 0.714 - 0.519
# epoch:9 | 0.741 - 0.539
# epoch:10 | 0.746 - 0.565
# epoch:11 | 0.746 - 0.583
# epoch:12 | 0.732 - 0.596
# epoch:13 | 0.782 - 0.612
# epoch:14 | 0.773 - 0.637
# epoch:15 | 0.805 - 0.643
# epoch:16 | 0.817 - 0.652
# epoch:17 | 0.82 - 0.67
# No handles with labels found to put in legend.
# epoch:18 | 0.825 - 0.671
# epoch:19 | 0.828 - 0.698
# ============== 4/16 ==============
# epoch:0 | 0.16 - 0.074
# epoch:1 | 0.484 - 0.118
# epoch:2 | 0.587 - 0.213
# epoch:3 | 0.604 - 0.324
# epoch:4 | 0.649 - 0.406
# epoch:5 | 0.66 - 0.493
# epoch:6 | 0.656 - 0.54
# epoch:7 | 0.668 - 0.591
# epoch:8 | 0.665 - 0.613
# epoch:9 | 0.729 - 0.657
# epoch:10 | 0.736 - 0.682
# epoch:11 | 0.744 - 0.706
# epoch:12 | 0.749 - 0.715
# epoch:13 | 0.745 - 0.733
# epoch:14 | 0.774 - 0.746
# epoch:15 | 0.783 - 0.759
# epoch:16 | 0.775 - 0.766
# epoch:17 | 0.797 - 0.777
# epoch:18 | 0.788 - 0.788
# No handles with labels found to put in legend.
# epoch:19 | 0.774 - 0.789
# ============== 5/16 ==============
# epoch:0 | 0.093 - 0.09
# epoch:1 | 0.097 - 0.146
# epoch:2 | 0.108 - 0.406
# epoch:3 | 0.142 - 0.53
# epoch:4 | 0.173 - 0.613
# epoch:5 | 0.201 - 0.649
# epoch:6 | 0.206 - 0.687
# epoch:7 | 0.167 - 0.706
# epoch:8 | 0.175 - 0.732
# epoch:9 | 0.187 - 0.747
# epoch:10 | 0.232 - 0.766
# epoch:11 | 0.211 - 0.778
# epoch:12 | 0.226 - 0.784
# epoch:13 | 0.223 - 0.798
# epoch:14 | 0.23 - 0.804
# epoch:15 | 0.261 - 0.814
# epoch:16 | 0.265 - 0.821
# epoch:17 | 0.269 - 0.827
# epoch:18 | 0.276 - 0.829
# No handles with labels found to put in legend.
# epoch:19 | 0.293 - 0.832
# ============== 6/16 ==============
# epoch:0 | 0.077 - 0.104
# epoch:1 | 0.076 - 0.29
# epoch:2 | 0.117 - 0.518
# epoch:3 | 0.115 - 0.629
# epoch:4 | 0.115 - 0.684
# epoch:5 | 0.115 - 0.726
# epoch:6 | 0.115 - 0.75
# epoch:7 | 0.115 - 0.765
# epoch:8 | 0.115 - 0.784
# epoch:9 | 0.115 - 0.799
# epoch:10 | 0.115 - 0.803
# epoch:11 | 0.115 - 0.821
# epoch:12 | 0.115 - 0.826
# epoch:13 | 0.115 - 0.831
# epoch:14 | 0.115 - 0.846
# epoch:15 | 0.115 - 0.855
# epoch:16 | 0.115 - 0.869
# epoch:17 | 0.115 - 0.874
# No handles with labels found to put in legend.
# epoch:18 | 0.115 - 0.88
# epoch:19 | 0.115 - 0.896
# ============== 7/16 ==============
# epoch:0 | 0.114 - 0.074
# epoch:1 | 0.115 - 0.398
# epoch:2 | 0.115 - 0.64
# epoch:3 | 0.115 - 0.692
# epoch:4 | 0.115 - 0.709
# epoch:5 | 0.115 - 0.748
# epoch:6 | 0.115 - 0.767
# epoch:7 | 0.115 - 0.795
# epoch:8 | 0.115 - 0.813
# epoch:9 | 0.115 - 0.825
# epoch:10 | 0.115 - 0.836
# epoch:11 | 0.115 - 0.863
# epoch:12 | 0.115 - 0.879
# epoch:13 | 0.115 - 0.904
# epoch:14 | 0.115 - 0.898
# epoch:15 | 0.115 - 0.904
# epoch:16 | 0.115 - 0.926
# epoch:17 | 0.115 - 0.942
# No handles with labels found to put in legend.
# epoch:18 | 0.115 - 0.958
# epoch:19 | 0.115 - 0.957
# ============== 8/16 ==============
# epoch:0 | 0.104 - 0.152
# epoch:1 | 0.099 - 0.574
# epoch:2 | 0.107 - 0.674
# epoch:3 | 0.107 - 0.722
# epoch:4 | 0.107 - 0.767
# epoch:5 | 0.107 - 0.805
# epoch:6 | 0.107 - 0.828
# epoch:7 | 0.107 - 0.819
# epoch:8 | 0.107 - 0.848
# epoch:9 | 0.107 - 0.859
# epoch:10 | 0.107 - 0.88
# epoch:11 | 0.107 - 0.838
# epoch:12 | 0.115 - 0.837
# epoch:13 | 0.115 - 0.927
# epoch:14 | 0.115 - 0.911
# epoch:15 | 0.115 - 0.918
# epoch:16 | 0.115 - 0.931
# epoch:17 | 0.115 - 0.969
# No handles with labels found to put in legend.
# epoch:18 | 0.115 - 0.955
# epoch:19 | 0.115 - 0.895
# ============== 9/16 ==============
# epoch:0 | 0.107 - 0.106
# epoch:1 | 0.107 - 0.534
# epoch:2 | 0.115 - 0.665
# epoch:3 | 0.115 - 0.679
# epoch:4 | 0.115 - 0.725
# epoch:5 | 0.115 - 0.759
# epoch:6 | 0.115 - 0.727
# epoch:7 | 0.115 - 0.794
# epoch:8 | 0.115 - 0.821
# epoch:9 | 0.115 - 0.851
# epoch:10 | 0.115 - 0.869
# epoch:11 | 0.115 - 0.824
# epoch:12 | 0.115 - 0.83
# epoch:13 | 0.115 - 0.812
# epoch:14 | 0.115 - 0.932
# epoch:15 | 0.115 - 0.912
# epoch:16 | 0.115 - 0.837
# epoch:17 | 0.115 - 0.904
# No handles with labels found to put in legend.
# epoch:18 | 0.115 - 0.957
# epoch:19 | 0.115 - 0.738
# ============== 10/16 ==============
# epoch:0 | 0.102 - 0.193
# epoch:1 | 0.102 - 0.637
# epoch:2 | 0.104 - 0.645
# epoch:3 | 0.102 - 0.69
# epoch:4 | 0.115 - 0.611
# epoch:5 | 0.115 - 0.719
# epoch:6 | 0.115 - 0.744
# epoch:7 | 0.115 - 0.824
# epoch:8 | 0.115 - 0.749
# epoch:9 | 0.115 - 0.755
# epoch:10 | 0.115 - 0.872
# epoch:11 | 0.115 - 0.691
# epoch:12 | 0.115 - 0.784
# epoch:13 | 0.115 - 0.8
# epoch:14 | 0.115 - 0.843
# epoch:15 | 0.115 - 0.825
# epoch:16 | 0.115 - 0.884
# epoch:17 | 0.115 - 0.946
# epoch:18 | 0.115 - 0.786
# No handles with labels found to put in legend.
# epoch:19 | 0.115 - 0.882
# ============== 11/16 ==============
# epoch:0 | 0.095 - 0.15
# epoch:1 | 0.115 - 0.493
# epoch:2 | 0.115 - 0.164
# epoch:3 | 0.115 - 0.596
# epoch:4 | 0.115 - 0.699
# epoch:5 | 0.115 - 0.665
# epoch:6 | 0.115 - 0.769
# epoch:7 | 0.115 - 0.719
# epoch:8 | 0.115 - 0.773
# epoch:9 | 0.115 - 0.821
# epoch:10 | 0.115 - 0.803
# epoch:11 | 0.115 - 0.81
# epoch:12 | 0.115 - 0.863
# epoch:13 | 0.115 - 0.727
# epoch:14 | 0.115 - 0.781
# epoch:15 | 0.115 - 0.909
# epoch:16 | 0.115 - 0.796
# epoch:17 | 0.115 - 0.836
# No handles with labels found to put in legend.
# epoch:18 | 0.115 - 0.922
# epoch:19 | 0.115 - 0.938
# ============== 12/16 ==============
# epoch:0 | 0.095 - 0.1
# epoch:1 | 0.115 - 0.447
# epoch:2 | 0.115 - 0.512
# epoch:3 | 0.115 - 0.339
# epoch:4 | 0.115 - 0.4
# epoch:5 | 0.115 - 0.491
# epoch:6 | 0.115 - 0.6
# epoch:7 | 0.115 - 0.586
# epoch:8 | 0.115 - 0.586
# epoch:9 | 0.115 - 0.209
# epoch:10 | 0.115 - 0.674
# epoch:11 | 0.115 - 0.73
# epoch:12 | 0.115 - 0.698
# epoch:13 | 0.115 - 0.781
# epoch:14 | 0.115 - 0.788
# epoch:15 | 0.115 - 0.772
# epoch:16 | 0.115 - 0.637
# epoch:17 | 0.115 - 0.784
# epoch:18 | 0.115 - 0.768
# No handles with labels found to put in legend.
# epoch:19 | 0.115 - 0.698
# ============== 13/16 ==============
# epoch:0 | 0.104 - 0.283
# epoch:1 | 0.104 - 0.369
# epoch:2 | 0.107 - 0.492
# epoch:3 | 0.115 - 0.49
# epoch:4 | 0.107 - 0.487
# epoch:5 | 0.107 - 0.465
# epoch:6 | 0.115 - 0.511
# epoch:7 | 0.107 - 0.591
# epoch:8 | 0.115 - 0.608
# epoch:9 | 0.115 - 0.594
# epoch:10 | 0.115 - 0.588
# epoch:11 | 0.115 - 0.6
# epoch:12 | 0.115 - 0.584
# epoch:13 | 0.115 - 0.609
# epoch:14 | 0.115 - 0.653
# epoch:15 | 0.115 - 0.682
# epoch:16 | 0.115 - 0.703
# epoch:17 | 0.115 - 0.618
# epoch:18 | 0.115 - 0.687
# No handles with labels found to put in legend.
# epoch:19 | 0.115 - 0.727
# ============== 14/16 ==============
# epoch:0 | 0.104 - 0.144
# epoch:1 | 0.099 - 0.115
# epoch:2 | 0.115 - 0.263
# epoch:3 | 0.115 - 0.392
# epoch:4 | 0.115 - 0.524
# epoch:5 | 0.115 - 0.568
# epoch:6 | 0.115 - 0.595
# epoch:7 | 0.115 - 0.542
# epoch:8 | 0.115 - 0.6
# epoch:9 | 0.115 - 0.601
# epoch:10 | 0.115 - 0.589
# epoch:11 | 0.115 - 0.592
# epoch:12 | 0.115 - 0.586
# epoch:13 | 0.115 - 0.59
# epoch:14 | 0.115 - 0.577
# epoch:15 | 0.115 - 0.607
# epoch:16 | 0.115 - 0.6
# epoch:17 | 0.115 - 0.61
# No handles with labels found to put in legend.
# epoch:18 | 0.115 - 0.662
# epoch:19 | 0.115 - 0.696
# ============== 15/16 ==============
# epoch:0 | 0.115 - 0.102
# epoch:1 | 0.115 - 0.279
# epoch:2 | 0.107 - 0.391
# epoch:3 | 0.107 - 0.387
# epoch:4 | 0.107 - 0.433
# epoch:5 | 0.107 - 0.392
# epoch:6 | 0.115 - 0.5
# epoch:7 | 0.115 - 0.47
# epoch:8 | 0.115 - 0.503
# epoch:9 | 0.115 - 0.514
# epoch:10 | 0.115 - 0.506
# epoch:11 | 0.115 - 0.512
# epoch:12 | 0.115 - 0.513
# epoch:13 | 0.115 - 0.511
# epoch:14 | 0.115 - 0.513
# epoch:15 | 0.115 - 0.503
# epoch:16 | 0.115 - 0.508
# epoch:17 | 0.115 - 0.518
# No handles with labels found to put in legend.
# epoch:18 | 0.115 - 0.515
# epoch:19 | 0.115 - 0.522
# ============== 16/16 ==============
# epoch:0 | 0.1 - 0.122
# epoch:1 | 0.1 - 0.267
# epoch:2 | 0.115 - 0.111
# epoch:3 | 0.115 - 0.382
# epoch:4 | 0.115 - 0.369
# epoch:5 | 0.115 - 0.394
# epoch:6 | 0.115 - 0.385
# epoch:7 | 0.115 - 0.389
# epoch:8 | 0.115 - 0.384
# epoch:9 | 0.115 - 0.394
# epoch:10 | 0.115 - 0.449
# epoch:11 | 0.115 - 0.48
# epoch:12 | 0.115 - 0.442
# epoch:13 | 0.115 - 0.505
# epoch:14 | 0.115 - 0.508
# epoch:15 | 0.115 - 0.49
# epoch:16 | 0.115 - 0.51
# epoch:17 | 0.115 - 0.437
# epoch:18 | 0.115 - 0.508
# epoch:19 | 0.115 - 0.502

# %% [markdown]
# # 7.

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# %%
# weight decay（가중치 감쇠） 설정 =======================
weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
# weight_decay_lambda = 0.1

# %%
network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

# %%
for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.10666666666666667, test acc:0.1063
# epoch:1, train acc:0.14, test acc:0.1412
# epoch:2, train acc:0.22, test acc:0.1684
# epoch:3, train acc:0.20666666666666667, test acc:0.1853
# epoch:4, train acc:0.24, test acc:0.2078
# epoch:5, train acc:0.27666666666666667, test acc:0.2332
# epoch:6, train acc:0.31666666666666665, test acc:0.2621
# epoch:7, train acc:0.36333333333333334, test acc:0.299
# epoch:8, train acc:0.36333333333333334, test acc:0.3085
# epoch:9, train acc:0.39, test acc:0.3418
# epoch:10, train acc:0.45, test acc:0.378
# epoch:11, train acc:0.45, test acc:0.4009
# epoch:12, train acc:0.53, test acc:0.4555
# epoch:13, train acc:0.56, test acc:0.4764
# epoch:14, train acc:0.5566666666666666, test acc:0.4945
# epoch:15, train acc:0.6366666666666667, test acc:0.5461
# epoch:16, train acc:0.65, test acc:0.578
# epoch:17, train acc:0.6966666666666667, test acc:0.5953
# epoch:18, train acc:0.6766666666666666, test acc:0.5895
# epoch:19, train acc:0.73, test acc:0.614
# epoch:20, train acc:0.74, test acc:0.6416
# epoch:21, train acc:0.7433333333333333, test acc:0.6324
# epoch:22, train acc:0.7333333333333333, test acc:0.6391
# epoch:23, train acc:0.76, test acc:0.6623
# epoch:24, train acc:0.7366666666666667, test acc:0.6452
# epoch:25, train acc:0.7866666666666666, test acc:0.6767
# epoch:26, train acc:0.73, test acc:0.6273
# epoch:27, train acc:0.7, test acc:0.6309
# epoch:28, train acc:0.72, test acc:0.6454
# epoch:29, train acc:0.76, test acc:0.6562
# epoch:30, train acc:0.7633333333333333, test acc:0.6702
# epoch:31, train acc:0.77, test acc:0.6722
# epoch:32, train acc:0.7833333333333333, test acc:0.6932
# epoch:33, train acc:0.7833333333333333, test acc:0.6828
# epoch:34, train acc:0.7766666666666666, test acc:0.6859
# epoch:35, train acc:0.8033333333333333, test acc:0.6964
# epoch:36, train acc:0.8, test acc:0.691
# epoch:37, train acc:0.8333333333333334, test acc:0.709
# epoch:38, train acc:0.7966666666666666, test acc:0.6768
# epoch:39, train acc:0.8, test acc:0.6931
# epoch:40, train acc:0.83, test acc:0.7079
# epoch:41, train acc:0.8266666666666667, test acc:0.7062
# epoch:42, train acc:0.8266666666666667, test acc:0.7066
# epoch:43, train acc:0.7933333333333333, test acc:0.6859
# epoch:44, train acc:0.68, test acc:0.6363
# epoch:45, train acc:0.8133333333333334, test acc:0.6924
# epoch:46, train acc:0.8433333333333334, test acc:0.7118
# epoch:47, train acc:0.85, test acc:0.7127
# epoch:48, train acc:0.8233333333333334, test acc:0.6885
# epoch:49, train acc:0.8466666666666667, test acc:0.7167
# epoch:50, train acc:0.8333333333333334, test acc:0.6915
# epoch:51, train acc:0.7133333333333334, test acc:0.6407
# epoch:52, train acc:0.78, test acc:0.6628
# epoch:53, train acc:0.8666666666666667, test acc:0.7222
# epoch:54, train acc:0.8833333333333333, test acc:0.7266
# epoch:55, train acc:0.82, test acc:0.7076
# epoch:56, train acc:0.86, test acc:0.7238
# epoch:57, train acc:0.88, test acc:0.7201
# epoch:58, train acc:0.8766666666666667, test acc:0.7184
# epoch:59, train acc:0.86, test acc:0.6959
# epoch:60, train acc:0.8366666666666667, test acc:0.7077
# epoch:61, train acc:0.8533333333333334, test acc:0.7114
# epoch:62, train acc:0.8866666666666667, test acc:0.7296
# epoch:63, train acc:0.8966666666666666, test acc:0.7288
# epoch:64, train acc:0.8833333333333333, test acc:0.7213
# epoch:65, train acc:0.85, test acc:0.7087
# epoch:66, train acc:0.8166666666666667, test acc:0.695
# epoch:67, train acc:0.8933333333333333, test acc:0.7262
# epoch:68, train acc:0.8966666666666666, test acc:0.7306
# epoch:69, train acc:0.9066666666666666, test acc:0.7368
# epoch:70, train acc:0.8966666666666666, test acc:0.7318
# epoch:71, train acc:0.8933333333333333, test acc:0.7228
# epoch:72, train acc:0.9233333333333333, test acc:0.7357
# epoch:73, train acc:0.8766666666666667, test acc:0.6937
# epoch:74, train acc:0.89, test acc:0.7201
# epoch:75, train acc:0.9133333333333333, test acc:0.7367
# epoch:76, train acc:0.8533333333333334, test acc:0.7121
# epoch:77, train acc:0.7566666666666667, test acc:0.6421
# epoch:78, train acc:0.9166666666666666, test acc:0.7343
# epoch:79, train acc:0.9133333333333333, test acc:0.7238
# epoch:80, train acc:0.8666666666666667, test acc:0.7072
# epoch:81, train acc:0.9133333333333333, test acc:0.7314
# epoch:82, train acc:0.9333333333333333, test acc:0.7377
# epoch:83, train acc:0.93, test acc:0.7347
# epoch:84, train acc:0.93, test acc:0.7402
# epoch:85, train acc:0.92, test acc:0.7351
# epoch:86, train acc:0.9366666666666666, test acc:0.741
# epoch:87, train acc:0.9466666666666667, test acc:0.7432
# epoch:88, train acc:0.9233333333333333, test acc:0.729
# epoch:89, train acc:0.9466666666666667, test acc:0.7435
# epoch:90, train acc:0.9466666666666667, test acc:0.7381
# epoch:91, train acc:0.9433333333333334, test acc:0.7381
# epoch:92, train acc:0.9433333333333334, test acc:0.7439
# epoch:93, train acc:0.9533333333333334, test acc:0.7439
# epoch:94, train acc:0.9566666666666667, test acc:0.7389
# epoch:95, train acc:0.96, test acc:0.727
# epoch:96, train acc:0.6933333333333334, test acc:0.627
# epoch:97, train acc:0.91, test acc:0.7213
# epoch:98, train acc:0.9366666666666666, test acc:0.7432
# epoch:99, train acc:0.9466666666666667, test acc:0.7458
# epoch:100, train acc:0.9633333333333334, test acc:0.7462
# epoch:101, train acc:0.96, test acc:0.743
# epoch:102, train acc:0.9433333333333334, test acc:0.746
# epoch:103, train acc:0.9533333333333334, test acc:0.7459
# epoch:104, train acc:0.9533333333333334, test acc:0.7434
# epoch:105, train acc:0.9666666666666667, test acc:0.7527
# epoch:106, train acc:0.9133333333333333, test acc:0.7088
# epoch:107, train acc:0.9133333333333333, test acc:0.7278
# epoch:108, train acc:0.9633333333333334, test acc:0.7519
# epoch:109, train acc:0.96, test acc:0.7485
# epoch:110, train acc:0.9666666666666667, test acc:0.7509
# epoch:111, train acc:0.9766666666666667, test acc:0.7506
# epoch:112, train acc:0.96, test acc:0.7346
# epoch:113, train acc:0.9533333333333334, test acc:0.7408
# epoch:114, train acc:0.9733333333333334, test acc:0.7383
# epoch:115, train acc:0.9466666666666667, test acc:0.7396
# epoch:116, train acc:0.9833333333333333, test acc:0.7455
# epoch:117, train acc:0.96, test acc:0.7455
# epoch:118, train acc:0.94, test acc:0.7327
# epoch:119, train acc:0.9533333333333334, test acc:0.7404
# epoch:120, train acc:0.98, test acc:0.7512
# epoch:121, train acc:0.8833333333333333, test acc:0.713
# epoch:122, train acc:0.9733333333333334, test acc:0.7446
# epoch:123, train acc:0.98, test acc:0.7506
# epoch:124, train acc:0.9833333333333333, test acc:0.752
# epoch:125, train acc:0.9866666666666667, test acc:0.7519
# epoch:126, train acc:0.99, test acc:0.7504
# epoch:127, train acc:0.99, test acc:0.7548
# epoch:128, train acc:0.9666666666666667, test acc:0.7339
# epoch:129, train acc:0.9866666666666667, test acc:0.7518
# epoch:130, train acc:0.98, test acc:0.754
# epoch:131, train acc:0.9866666666666667, test acc:0.7528
# epoch:132, train acc:0.9833333333333333, test acc:0.7487
# epoch:133, train acc:0.98, test acc:0.7483
# epoch:134, train acc:0.9633333333333334, test acc:0.7259
# epoch:135, train acc:0.79, test acc:0.6618
# epoch:136, train acc:0.97, test acc:0.7425
# epoch:137, train acc:0.9866666666666667, test acc:0.7523
# epoch:138, train acc:0.9933333333333333, test acc:0.7556
# epoch:139, train acc:0.9966666666666667, test acc:0.7553
# epoch:140, train acc:0.9933333333333333, test acc:0.7544
# epoch:141, train acc:0.99, test acc:0.7457
# epoch:142, train acc:1.0, test acc:0.7542
# epoch:143, train acc:0.9966666666666667, test acc:0.7499
# epoch:144, train acc:0.9933333333333333, test acc:0.7571
# epoch:145, train acc:0.99, test acc:0.7554
# epoch:146, train acc:0.99, test acc:0.7519
# epoch:147, train acc:0.99, test acc:0.7564
# epoch:148, train acc:0.9966666666666667, test acc:0.7562
# epoch:149, train acc:0.9966666666666667, test acc:0.7588
# epoch:150, train acc:0.99, test acc:0.7465
# epoch:151, train acc:0.9966666666666667, test acc:0.759
# epoch:152, train acc:0.9866666666666667, test acc:0.7575
# epoch:153, train acc:0.9966666666666667, test acc:0.7517
# epoch:154, train acc:0.9966666666666667, test acc:0.7588
# epoch:155, train acc:0.9966666666666667, test acc:0.7587
# epoch:156, train acc:0.9733333333333334, test acc:0.7554
# epoch:157, train acc:0.9966666666666667, test acc:0.7604
# epoch:158, train acc:1.0, test acc:0.7545
# epoch:159, train acc:1.0, test acc:0.7581
# epoch:160, train acc:0.9966666666666667, test acc:0.7598
# epoch:161, train acc:1.0, test acc:0.7556
# epoch:162, train acc:0.99, test acc:0.7407
# epoch:163, train acc:0.9866666666666667, test acc:0.7491
# epoch:164, train acc:1.0, test acc:0.7598
# epoch:165, train acc:1.0, test acc:0.7597
# epoch:166, train acc:0.9966666666666667, test acc:0.7587
# epoch:167, train acc:1.0, test acc:0.7587
# epoch:168, train acc:1.0, test acc:0.7569
# epoch:169, train acc:1.0, test acc:0.7487
# epoch:170, train acc:1.0, test acc:0.7563
# epoch:171, train acc:1.0, test acc:0.7587
# epoch:172, train acc:0.9733333333333334, test acc:0.7463
# epoch:173, train acc:0.9933333333333333, test acc:0.7434
# epoch:174, train acc:0.9966666666666667, test acc:0.7622
# epoch:175, train acc:1.0, test acc:0.761
# epoch:176, train acc:1.0, test acc:0.7588
# epoch:177, train acc:1.0, test acc:0.7611
# epoch:178, train acc:1.0, test acc:0.7588
# epoch:179, train acc:1.0, test acc:0.7613
# epoch:180, train acc:1.0, test acc:0.7514
# epoch:181, train acc:1.0, test acc:0.76
# epoch:182, train acc:1.0, test acc:0.7615
# epoch:183, train acc:1.0, test acc:0.7595
# epoch:184, train acc:1.0, test acc:0.7548
# epoch:185, train acc:1.0, test acc:0.7613
# epoch:186, train acc:1.0, test acc:0.76
# epoch:187, train acc:1.0, test acc:0.7593
# epoch:188, train acc:1.0, test acc:0.7593
# epoch:189, train acc:1.0, test acc:0.7474
# epoch:190, train acc:1.0, test acc:0.7593
# epoch:191, train acc:1.0, test acc:0.7596
# epoch:192, train acc:1.0, test acc:0.7592
# epoch:193, train acc:1.0, test acc:0.7586
# epoch:194, train acc:1.0, test acc:0.7596
# epoch:195, train acc:1.0, test acc:0.7606
# epoch:196, train acc:1.0, test acc:0.7591
# epoch:197, train acc:1.0, test acc:0.7607
# epoch:198, train acc:1.0, test acc:0.7598
# epoch:199, train acc:1.0, test acc:0.7617
# epoch:200, train acc:1.0, test acc:0.7625

# %%
# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # 8.

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# %%
use_dropout = True  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2

# %%
network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=601, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list
# Out:
# 58 ===
# train loss:0.6112036667291022
# train loss:0.7181999093535357
# train loss:0.7487972986494357
# === epoch:470, train acc:0.74, test acc:0.6487 ===
# train loss:0.6810466669451796
# train loss:0.6995404824763729
# train loss:0.7706253105071802
# === epoch:471, train acc:0.7433333333333333, test acc:0.6582 ===
# train loss:0.8378936376775181
# train loss:0.7660497477714627
# train loss:0.6930813748090644
# === epoch:472, train acc:0.7466666666666667, test acc:0.6547 ===
# train loss:0.7064249368357752
# train loss:0.6820199375384477
# train loss:0.7247055460190542
# === epoch:473, train acc:0.7533333333333333, test acc:0.6712 ===
# train loss:0.7121457116702977
# train loss:0.777822466494639
# train loss:0.7438856350783141
# === epoch:474, train acc:0.7566666666666667, test acc:0.6629 ===
# train loss:0.768305517617392
# train loss:0.7010499939130148
# train loss:0.7091842522506728
# === epoch:475, train acc:0.73, test acc:0.6526 ===
# train loss:0.7610833647618
# train loss:0.7341680797254113
# train loss:0.659499437679097
# === epoch:476, train acc:0.7533333333333333, test acc:0.6584 ===
# train loss:0.7458381637353364
# train loss:0.8084774716474024
# train loss:0.6705647893316469
# === epoch:477, train acc:0.78, test acc:0.6673 ===
# train loss:0.7440909869411496
# train loss:0.5984813639759382
# train loss:0.7857124709194117
# === epoch:478, train acc:0.76, test acc:0.6607 ===
# train loss:0.8449223680570559
# train loss:0.7347628628369901
# train loss:0.5937813365361522
# === epoch:479, train acc:0.7733333333333333, test acc:0.6708 ===
# train loss:0.7636059629909782
# train loss:0.6745893612429278
# train loss:0.6995274074574475
# === epoch:480, train acc:0.77, test acc:0.6716 ===
# train loss:0.6266835565998137
# train loss:0.6898014277416677
# train loss:0.6885681234581211
# === epoch:481, train acc:0.7633333333333333, test acc:0.6658 ===
# train loss:0.6982602277090415
# train loss:0.7096058802623685
# train loss:0.7242716183882387
# === epoch:482, train acc:0.76, test acc:0.6733 ===
# train loss:0.7162945170848939
# train loss:0.6880491828707543
# train loss:0.6895130645133949
# === epoch:483, train acc:0.77, test acc:0.6749 ===
# train loss:0.691790840210257
# train loss:0.7593112990682941
# train loss:0.6650415279944766
# === epoch:484, train acc:0.75, test acc:0.6698 ===
# train loss:0.7089306647361613
# train loss:0.8125003410677778
# train loss:0.7272264116839392
# === epoch:485, train acc:0.7633333333333333, test acc:0.6727 ===
# train loss:0.6433565244189982
# train loss:0.7891961069239259
# train loss:0.7079671674197724
# === epoch:486, train acc:0.7566666666666667, test acc:0.6758 ===
# train loss:0.67760228833412
# train loss:0.7513023119330592
# train loss:0.681859640090752
# === epoch:487, train acc:0.7666666666666667, test acc:0.674 ===
# train loss:0.6908154425890015
# train loss:0.6876885363331509
# train loss:0.6887076767580689
# === epoch:488, train acc:0.7566666666666667, test acc:0.6713 ===
# train loss:0.6956415237345758
# train loss:0.7181531101495101
# train loss:0.7254774791701739
# === epoch:489, train acc:0.76, test acc:0.6691 ===
# train loss:0.5944098679155432
# train loss:0.7437951821952247
# train loss:0.684430470085466
# === epoch:490, train acc:0.7533333333333333, test acc:0.6603 ===
# train loss:0.7015078656520837
# train loss:0.663318246721015
# train loss:0.743711661904899
# === epoch:491, train acc:0.75, test acc:0.6596 ===
# train loss:0.6626461773890233
# train loss:0.7865616122964522
# train loss:0.7661073718134177
# === epoch:492, train acc:0.7433333333333333, test acc:0.6594 ===
# train loss:0.7388164128624644
# train loss:0.5684863518054123
# train loss:0.692786722899162
# === epoch:493, train acc:0.7366666666666667, test acc:0.6507 ===
# train loss:0.7185488265520589
# train loss:0.6322389109199684
# train loss:0.617531426667897
# === epoch:494, train acc:0.75, test acc:0.6619 ===
# train loss:0.6193391109813803
# train loss:0.7729970201571537
# train loss:0.7065871612155101
# === epoch:495, train acc:0.7466666666666667, test acc:0.6619 ===
# train loss:0.6674560309456574
# train loss:0.6654018901955976
# train loss:0.7075758214424898
# === epoch:496, train acc:0.7233333333333334, test acc:0.6441 ===
# train loss:0.8082079770083931
# train loss:0.7816198789678794
# train loss:0.67894021976542
# === epoch:497, train acc:0.7233333333333334, test acc:0.645 ===
# train loss:0.7169003037529015
# train loss:0.713927500674264
# train loss:0.6114539731582216
# === epoch:498, train acc:0.7566666666666667, test acc:0.6599 ===
# train loss:0.7339625917838021
# train loss:0.6948827516782196
# train loss:0.8651088554701729
# === epoch:499, train acc:0.7533333333333333, test acc:0.6608 ===
# train loss:0.5985003253354716
# train loss:0.6344636119271561
# train loss:0.7017132313226665
# === epoch:500, train acc:0.7633333333333333, test acc:0.6594 ===
# train loss:0.7352124673359195
# train loss:0.6395546336557477
# train loss:0.6931993740645409
# === epoch:501, train acc:0.74, test acc:0.6525 ===
# train loss:0.7260459811217078
# train loss:0.5762466875926919
# train loss:0.7036279867617261
# === epoch:502, train acc:0.7333333333333333, test acc:0.6485 ===
# train loss:0.7689233982446484
# train loss:0.6916762695889689
# train loss:0.6441777699542885
# === epoch:503, train acc:0.76, test acc:0.6614 ===
# train loss:0.7168680351176093
# train loss:0.6807042819137513
# train loss:0.7298174255708909
# === epoch:504, train acc:0.7666666666666667, test acc:0.6719 ===
# train loss:0.6339908449867679
# train loss:0.6534194115517268
# train loss:0.6881890179864247
# === epoch:505, train acc:0.7566666666666667, test acc:0.6679 ===
# train loss:0.7844276291802096
# train loss:0.6740058299524193
# train loss:0.6641479919741358
# === epoch:506, train acc:0.7566666666666667, test acc:0.6611 ===
# train loss:0.6663593990833716
# train loss:0.6999137567119014
# train loss:0.7199885915801797
# === epoch:507, train acc:0.7566666666666667, test acc:0.6647 ===
# train loss:0.61844981914774
# train loss:0.6551433672140149
# train loss:0.697634588394355
# === epoch:508, train acc:0.7566666666666667, test acc:0.6631 ===
# train loss:0.7442233059070945
# train loss:0.6816487053059737
# train loss:0.6682029624179222
# === epoch:509, train acc:0.7466666666666667, test acc:0.6537 ===
# train loss:0.7159755691087022
# train loss:0.6370673604807131
# train loss:0.7361163117649437
# === epoch:510, train acc:0.7533333333333333, test acc:0.6616 ===
# train loss:0.7238774836381979
# train loss:0.763308756344168
# train loss:0.7101887500497823
# === epoch:511, train acc:0.7666666666666667, test acc:0.6682 ===
# train loss:0.8350178215027466
# train loss:0.717844188786332
# train loss:0.5113631462490137
# === epoch:512, train acc:0.7566666666666667, test acc:0.6592 ===
# train loss:0.6595654821411071
# train loss:0.6172958554299685
# train loss:0.7889823377265313
# === epoch:513, train acc:0.7666666666666667, test acc:0.6692 ===
# train loss:0.6808232794885687
# train loss:0.7088094938052246
# train loss:0.7036104420958686
# === epoch:514, train acc:0.7633333333333333, test acc:0.6632 ===
# train loss:0.6840663676066167
# train loss:0.6036757788705914
# train loss:0.7712850384960107
# === epoch:515, train acc:0.7333333333333333, test acc:0.6444 ===
# train loss:0.7061761564259662
# train loss:0.715042876802196
# train loss:0.8142782947123789
# === epoch:516, train acc:0.7566666666666667, test acc:0.6551 ===
# train loss:0.6190622674102247
# train loss:0.7036005542376601
# train loss:0.5763528478623129
# === epoch:517, train acc:0.7566666666666667, test acc:0.655 ===
# train loss:0.7037483136116487
# train loss:0.8201761415659427
# train loss:0.7334378983819891
# === epoch:518, train acc:0.77, test acc:0.6677 ===
# train loss:0.5986365294069801
# train loss:0.7760838002673586
# train loss:0.5793733325831449
# === epoch:519, train acc:0.7733333333333333, test acc:0.6751 ===
# train loss:0.6778706484185766
# train loss:0.6928181726868218
# train loss:0.6846974589813064
# === epoch:520, train acc:0.7666666666666667, test acc:0.671 ===
# train loss:0.6714272128293084
# train loss:0.6450053948096738
# train loss:0.7870041802811794
# === epoch:521, train acc:0.7866666666666666, test acc:0.6754 ===
# train loss:0.6666728070699977
# train loss:0.6875159322515126
# train loss:0.6436780138509763
# === epoch:522, train acc:0.77, test acc:0.6664 ===
# train loss:0.6533844944555603
# train loss:0.5788593247171172
# train loss:0.6143177090545089
# === epoch:523, train acc:0.7633333333333333, test acc:0.6657 ===
# train loss:0.7027994723726642
# train loss:0.5931542529402853
# train loss:0.717181716058539
# === epoch:524, train acc:0.78, test acc:0.6684 ===
# train loss:0.7116458159381129
# train loss:0.6383858782903217
# train loss:0.6375284486188886
# === epoch:525, train acc:0.7833333333333333, test acc:0.669 ===
# train loss:0.6899449560708463
# train loss:0.6373071375043711
# train loss:0.707383659625344
# === epoch:526, train acc:0.78, test acc:0.6698 ===
# train loss:0.6849127747773395
# train loss:0.6540489756243563
# train loss:0.5843809141780736
# === epoch:527, train acc:0.76, test acc:0.6643 ===
# train loss:0.6334054824435371
# train loss:0.6609500826131496
# train loss:0.598211322512886
# === epoch:528, train acc:0.7633333333333333, test acc:0.6737 ===
# train loss:0.6331302905008687
# train loss:0.6069644183058766
# train loss:0.5863655306484159
# === epoch:529, train acc:0.7633333333333333, test acc:0.6719 ===
# train loss:0.6747773420559688
# train loss:0.5794565683607579
# train loss:0.6420163426609368
# === epoch:530, train acc:0.78, test acc:0.6777 ===
# train loss:0.7173289341745519
# train loss:0.6384216179702396
# train loss:0.6415613549470881
# === epoch:531, train acc:0.7766666666666666, test acc:0.6836 ===
# train loss:0.5701347906408346
# train loss:0.7002738462359959
# train loss:0.6100628029207297
# === epoch:532, train acc:0.79, test acc:0.6868 ===
# train loss:0.6849787317201955
# train loss:0.6306416149352698
# train loss:0.6998989423078832
# === epoch:533, train acc:0.7833333333333333, test acc:0.6829 ===
# train loss:0.6765671813928356
# train loss:0.7667277828451295
# train loss:0.6355102504030663
# === epoch:534, train acc:0.7966666666666666, test acc:0.6878 ===
# train loss:0.5970753803908705
# train loss:0.6298655603067639
# train loss:0.7658861565940248
# === epoch:535, train acc:0.7966666666666666, test acc:0.6885 ===
# train loss:0.5943438189895038
# train loss:0.6441444637897469
# train loss:0.667419039955673
# === epoch:536, train acc:0.78, test acc:0.6779 ===
# train loss:0.7102366877727857
# train loss:0.598897585608468
# train loss:0.6251479518270401
# === epoch:537, train acc:0.7633333333333333, test acc:0.6683 ===
# train loss:0.6458794557413517
# train loss:0.646918329724386
# train loss:0.653319833080011
# === epoch:538, train acc:0.7833333333333333, test acc:0.6785 ===
# train loss:0.6015170198684242
# train loss:0.7708864082694002
# train loss:0.5598455587579055
# === epoch:539, train acc:0.7866666666666666, test acc:0.6843 ===
# train loss:0.7079633879375494
# train loss:0.6349392039232482
# train loss:0.6931852970356738
# === epoch:540, train acc:0.78, test acc:0.671 ===
# train loss:0.578382007273833
# train loss:0.6027693637514966
# train loss:0.6615695953460486
# === epoch:541, train acc:0.77, test acc:0.6645 ===
# train loss:0.5949800324086165
# train loss:0.5980170038708388
# train loss:0.6107858711442209
# === epoch:542, train acc:0.7733333333333333, test acc:0.6674 ===
# train loss:0.6938348509050272
# train loss:0.63562003002377
# train loss:0.5958687654836065
# === epoch:543, train acc:0.7733333333333333, test acc:0.6694 ===
# train loss:0.6517749456337357
# train loss:0.771127973603995
# train loss:0.6465632838408331
# === epoch:544, train acc:0.7966666666666666, test acc:0.6771 ===
# train loss:0.6417068614732151
# train loss:0.5544913598197141
# train loss:0.6877599305670141
# === epoch:545, train acc:0.7933333333333333, test acc:0.6845 ===
# train loss:0.5208372072356151
# train loss:0.6756433362689782
# train loss:0.6415977662691017
# === epoch:546, train acc:0.7966666666666666, test acc:0.684 ===
# train loss:0.8042617196480072
# train loss:0.6124715682825613
# train loss:0.5940453107913267
# === epoch:547, train acc:0.7733333333333333, test acc:0.6769 ===
# train loss:0.6114128426336408
# train loss:0.52937286920907
# train loss:0.5488629175384033
# === epoch:548, train acc:0.78, test acc:0.675 ===
# train loss:0.6730191109967726
# train loss:0.638044457752486
# train loss:0.609551334173323
# === epoch:549, train acc:0.7566666666666667, test acc:0.6663 ===
# train loss:0.5825837941509584
# train loss:0.6190804203272201
# train loss:0.6291039862189161
# === epoch:550, train acc:0.7266666666666667, test acc:0.6613 ===
# train loss:0.7035822521357302
# train loss:0.5507363375011226
# train loss:0.676215288873684
# === epoch:551, train acc:0.7766666666666666, test acc:0.6719 ===
# train loss:0.4919243336729504
# train loss:0.6764795837881958
# train loss:0.5981722499827173
# === epoch:552, train acc:0.77, test acc:0.6663 ===
# train loss:0.6757810707915627
# train loss:0.6756316759593064
# train loss:0.6507458731623784
# === epoch:553, train acc:0.7933333333333333, test acc:0.6754 ===
# train loss:0.7308828560830338
# train loss:0.62267022556757
# train loss:0.7090940831001054
# === epoch:554, train acc:0.7766666666666666, test acc:0.6703 ===
# train loss:0.6850452636090489
# train loss:0.6538303349234235
# train loss:0.70320686542298
# === epoch:555, train acc:0.7766666666666666, test acc:0.6756 ===
# train loss:0.6093038711878465
# train loss:0.561186118420114
# train loss:0.5963534631342252
# === epoch:556, train acc:0.7866666666666666, test acc:0.6796 ===
# train loss:0.6914409529786185
# train loss:0.7125179374272261
# train loss:0.5741680158585282
# === epoch:557, train acc:0.7733333333333333, test acc:0.6722 ===
# train loss:0.737468940207257
# train loss:0.6670611279984527
# train loss:0.5732877738894554
# === epoch:558, train acc:0.7833333333333333, test acc:0.6749 ===
# train loss:0.5721451391881589
# train loss:0.5922635125173865
# train loss:0.6298203988478385
# === epoch:559, train acc:0.7766666666666666, test acc:0.6755 ===
# train loss:0.6640333071647191
# train loss:0.729049095547731
# train loss:0.6780095275723349
# === epoch:560, train acc:0.7766666666666666, test acc:0.6753 ===
# train loss:0.6536101338414436
# train loss:0.5814395732019156
# train loss:0.589494143152973
# === epoch:561, train acc:0.7833333333333333, test acc:0.6848 ===
# train loss:0.6710843073971329
# train loss:0.6729892569628493
# train loss:0.5321965155754934
# === epoch:562, train acc:0.7966666666666666, test acc:0.6873 ===
# train loss:0.6708309514709164
# train loss:0.7030293144909584
# train loss:0.6234945823274792
# === epoch:563, train acc:0.7966666666666666, test acc:0.6911 ===
# train loss:0.5704607478635525
# train loss:0.6977516612755177
# train loss:0.6622833765199259
# === epoch:564, train acc:0.8233333333333334, test acc:0.6944 ===
# train loss:0.5812070446157598
# train loss:0.6281997654578858
# train loss:0.6304299015933787
# === epoch:565, train acc:0.8266666666666667, test acc:0.6963 ===
# train loss:0.6046646750332052
# train loss:0.6109829875702676
# train loss:0.6506996090396759
# === epoch:566, train acc:0.82, test acc:0.6937 ===
# train loss:0.5302188303031327
# train loss:0.6657131674623031
# train loss:0.5354558543917405
# === epoch:567, train acc:0.8166666666666667, test acc:0.6944 ===
# train loss:0.6797174980668853
# train loss:0.6297800338979007
# train loss:0.6132190007316047
# === epoch:568, train acc:0.7933333333333333, test acc:0.6908 ===
# train loss:0.6540409242988388
# train loss:0.6010356758286459
# train loss:0.7077239047542574
# === epoch:569, train acc:0.7966666666666666, test acc:0.6918 ===
# train loss:0.5882419877494418
# train loss:0.5540753653251
# train loss:0.6889935573777166
# === epoch:570, train acc:0.7933333333333333, test acc:0.6849 ===
# train loss:0.6433348437613791
# train loss:0.6072728034015425
# train loss:0.5964658993147747
# === epoch:571, train acc:0.7933333333333333, test acc:0.6844 ===
# train loss:0.6276059483815875
# train loss:0.6787066165916447
# train loss:0.5480755236762028
# === epoch:572, train acc:0.8, test acc:0.6876 ===
# train loss:0.6386527608379967
# train loss:0.6351567638746194
# train loss:0.5308410623693207
# === epoch:573, train acc:0.7866666666666666, test acc:0.6798 ===
# train loss:0.6038677876563647
# train loss:0.5813640992259625
# train loss:0.57131621555788
# === epoch:574, train acc:0.7966666666666666, test acc:0.6814 ===
# train loss:0.646029490046188
# train loss:0.7041394897793003
# train loss:0.7226213332139682
# === epoch:575, train acc:0.8066666666666666, test acc:0.6871 ===
# train loss:0.6667693516158851
# train loss:0.6674400831996016
# train loss:0.5490063711633476
# === epoch:576, train acc:0.8133333333333334, test acc:0.6909 ===
# train loss:0.7326748426022875
# train loss:0.5501560217167986
# train loss:0.671167213846011
# === epoch:577, train acc:0.83, test acc:0.6936 ===
# train loss:0.598751339165054
# train loss:0.561445775312602
# train loss:0.5634994379674975
# === epoch:578, train acc:0.82, test acc:0.6904 ===
# train loss:0.7390173597328316
# train loss:0.6197376630399303
# train loss:0.6653030094510147
# === epoch:579, train acc:0.81, test acc:0.6876 ===
# train loss:0.619238639007367
# train loss:0.6321035738701642
# train loss:0.5886644431660244
# === epoch:580, train acc:0.8033333333333333, test acc:0.6869 ===
# train loss:0.6170990441726274
# train loss:0.6379303010000247
# train loss:0.5939553905719278
# === epoch:581, train acc:0.7933333333333333, test acc:0.6786 ===
# train loss:0.6158886786747785
# train loss:0.5137223718438011
# train loss:0.607053200529445
# === epoch:582, train acc:0.78, test acc:0.6747 ===
# train loss:0.6132036116919081
# train loss:0.6035829467408984
# train loss:0.7003434807127484
# === epoch:583, train acc:0.81, test acc:0.6855 ===
# train loss:0.5268362306097653
# train loss:0.6822484481278274
# train loss:0.5314486074788042
# === epoch:584, train acc:0.82, test acc:0.6902 ===
# train loss:0.6718164853295828
# train loss:0.5729491315730708
# train loss:0.5764816942128939
# === epoch:585, train acc:0.8233333333333334, test acc:0.6933 ===
# train loss:0.6009408343462814
# train loss:0.5092617125549939
# train loss:0.6397745201947763
# === epoch:586, train acc:0.7966666666666666, test acc:0.6817 ===
# train loss:0.5728709064170299
# train loss:0.6766031406825883
# train loss:0.6954807061832697
# === epoch:587, train acc:0.8166666666666667, test acc:0.6824 ===
# train loss:0.5835313923246646
# train loss:0.5828786231778093
# train loss:0.5980594135878526
# === epoch:588, train acc:0.7966666666666666, test acc:0.678 ===
# train loss:0.5718981264910731
# train loss:0.5250370795539184
# train loss:0.5594168651952244
# === epoch:589, train acc:0.8, test acc:0.6782 ===
# train loss:0.5584889779076578
# train loss:0.5397795558097542
# train loss:0.5830151204600185
# === epoch:590, train acc:0.7933333333333333, test acc:0.6811 ===
# train loss:0.6345241545282003
# train loss:0.6180654932661898
# train loss:0.6315913686361193
# === epoch:591, train acc:0.82, test acc:0.6888 ===
# train loss:0.5769233096435431
# train loss:0.5813626842442325
# train loss:0.5474979123435529
# === epoch:592, train acc:0.8233333333333334, test acc:0.6953 ===
# train loss:0.6180318598622009
# train loss:0.621681830937934
# train loss:0.6355165382390242
# === epoch:593, train acc:0.8066666666666666, test acc:0.6844 ===
# train loss:0.5546954303357119
# train loss:0.5750430140024702
# train loss:0.5336442360550936
# === epoch:594, train acc:0.8133333333333334, test acc:0.6912 ===
# train loss:0.6379158748993706
# train loss:0.5039617448403412
# train loss:0.622090251942583
# === epoch:595, train acc:0.8166666666666667, test acc:0.693 ===
# train loss:0.6090344831838067
# train loss:0.5188358374006987
# train loss:0.5862445357336308
# === epoch:596, train acc:0.8233333333333334, test acc:0.6954 ===
# train loss:0.6013327830399388
# train loss:0.5718680073850758
# train loss:0.6111757863776432
# === epoch:597, train acc:0.8166666666666667, test acc:0.6933 ===
# train loss:0.4899316448879171
# train loss:0.6235483028412163
# train loss:0.5909239618705151
# === epoch:598, train acc:0.8066666666666666, test acc:0.686 ===
# train loss:0.6825920555595191
# train loss:0.5293178784320672
# train loss:0.6803362861641553
# === epoch:599, train acc:0.82, test acc:0.6887 ===
# train loss:0.5987968902894428
# train loss:0.58849473810631
# train loss:0.5715546651016671
# === epoch:600, train acc:0.8066666666666666, test acc:0.6833 ===
# train loss:0.6328986540860339
# train loss:0.6065351513986148
# train loss:0.5992225926459999
# === epoch:601, train acc:0.81, test acc:0.6839 ===
# train loss:0.5858707911093698
# train loss:0.693639681489904
# =============== Final Test Accuracy ===============
# test acc:0.6834

# %%
# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # 9.

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %%
def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list

# %%
# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list
# Out:
# val acc:0.32 | lr:0.000561896679993351, weight decay:1.4381787592610407e-06
# val acc:0.14 | lr:2.2234542167598615e-05, weight decay:2.084486073647257e-06
# val acc:0.09 | lr:0.00024833183643810673, weight decay:1.4611511298431247e-07
# val acc:0.18 | lr:0.00023069160005647528, weight decay:6.0154569803451605e-06
# val acc:0.74 | lr:0.006198177443058704, weight decay:1.5951064172910767e-08
# val acc:0.12 | lr:1.6128194110716008e-05, weight decay:3.93703473235913e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-157-f01c53cb6e2d> in <module>
#       9     # ================================================
#      10
# ---> 11     val_acc_list, train_acc_list = __train(lr, weight_decay)
#      12     print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
#      13     key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
#
# <ipython-input-156-2680f66e8298> in __train(lr, weight_decay, epocs)
#       5                       epochs=epocs, mini_batch_size=100,
#       6                       optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
# ----> 7     trainer.train()
#       8
#       9     return trainer.test_acc_list, trainer.train_acc_list
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\trainer.py in train(self)
#      69     def train(self):
#      70         for i in range(self.max_iter):
# ---> 71             self.train_step()
#      72
#      73         test_acc = self.network.accuracy(self.x_test, self.t_test)
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\trainer.py in train_step(self)
#      60
#      61             train_acc = self.network.accuracy(x_train_sample, t_train_sample)
# ---> 62             test_acc = self.network.accuracy(x_test_sample, t_test_sample)
#      63             self.train_acc_list.append(train_acc)
#      64             self.test_acc_list.append(test_acc)
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\multi_layer_net.py in accuracy(self, x, t)
#      95
#      96     def accuracy(self, x, t):
# ---> 97         y = self.predict(x)
#      98         y = np.argmax(y, axis=1)
#      99         if t.ndim != 1 : t = np.argmax(t, axis=1)
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\multi_layer_net.py in predict(self, x)
#      69     def predict(self, x):
#      70         for layer in self.layers.values():
# ---> 71             x = layer.forward(x)
#      72
#      73         return x
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\layers.py in forward(self, x)
#      55         self.x = x
#      56
# ---> 57         out = np.dot(self.x, self.W) + self.b
#      58
#      59         return out
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()

# %%
def find_num(num):
    answer = 0
    while True:
        if 1 <= num < 10:
            return answer
        elif num < 1:
            answer -= 1
            num *= 10
        elif num >= 10:
            answer += 1
            num /= 10

# %%
optimization_trial = 30

weight_decay_min = -8
weight_decay_max = -4
lr_min = -6
lr_max = -2


for a in range(3):
    weight_decay_bests = []
    lr_bests = []

    results_val = {}
    results_train = {}
    for _ in range(optimization_trial):
        # 탐색한 하이퍼파라미터의 범위 지정===============
        weight_decay = 10 ** np.random.uniform(weight_decay_min, weight_decay_max)
        lr = 10 ** np.random.uniform(lr_min, lr_max)
        # ================================================

        val_acc_list, train_acc_list = __train(lr, weight_decay)
        print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
        # key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
        key = (lr, weight_decay)

        results_val[key] = val_acc_list
        results_train[key] = train_acc_list

    # 그래프 그리기========================================================
    print("=========== Hyper-Parameter Optimization Result ===========")
    graph_draw_num = 20
    col_num = 5
    row_num = int(np.ceil(graph_draw_num / col_num))
    i = 0

    for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
        print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + "lr:" + str(key[0]) + ", weight decay:" + str(key[1]))
        if (i < 6):
            weight_decay_bests.append(key[0])
            lr_bests.append(key[1])

        plt.subplot(row_num, col_num, i+1)
        plt.title("Best-" + str(i+1))
        plt.ylim(0.0, 1.0)
        if i % 5: plt.yticks([])
        plt.xticks([])
        x = np.arange(len(val_acc_list))
        plt.plot(x, val_acc_list)
        plt.plot(x, results_train[key], "--")
        i += 1

        if i >= graph_draw_num:
            break

    plt.show()

    weight_decay_min = find_num(min(weight_decay_bests))
    weight_decay_max = find_num(max(weight_decay_bests)) + 1
    lr_min = find_num(min(lr_bests))
    lr_max = find_num(max(lr_bests)) + 1

    print("weight decay min:",weight_decay_min, ", weight decay max:", weight_decay_max, ", lr min:", lr_min, ", lr max:", lr_max)
# Out:
# val acc:0.4 | lr:0.001462524294862965, weight decay:3.357565594631702e-07
# val acc:0.1 | lr:1.7614813428783584e-05, weight decay:5.7747469452300216e-08
# val acc:0.12 | lr:1.881862223921729e-05, weight decay:1.3758169094063597e-07
# val acc:0.7 | lr:0.004639939561069104, weight decay:8.406673302506419e-07
# val acc:0.17 | lr:1.8726502543195473e-05, weight decay:1.7385656070212144e-06
# val acc:0.06 | lr:2.4412302678033735e-05, weight decay:1.9844587724611774e-06
# val acc:0.72 | lr:0.008085959771571434, weight decay:5.7566367206931485e-06
# val acc:0.1 | lr:2.6030184493034565e-05, weight decay:7.818090042882667e-05
# val acc:0.55 | lr:0.001757776983822533, weight decay:3.036570407512711e-06
# val acc:0.11 | lr:1.1066799823180722e-06, weight decay:5.4864843026001385e-05
# val acc:0.09 | lr:3.6729193438926125e-05, weight decay:3.973451739261287e-05
# val acc:0.39 | lr:0.0007267081883997702, weight decay:2.920232423960345e-08
# val acc:0.03 | lr:1.397148046117023e-06, weight decay:3.074987930774133e-05
# val acc:0.17 | lr:0.00045853837031889483, weight decay:2.218008472955756e-08
# val acc:0.5 | lr:0.0018829571269024172, weight decay:1.0954389378122464e-08
# val acc:0.33 | lr:0.0009385721914522465, weight decay:6.080375215630573e-07
# val acc:0.11 | lr:1.4767610715040775e-06, weight decay:8.486760124207892e-05
# val acc:0.09 | lr:0.0001391534033158097, weight decay:2.3905867922130842e-06
# val acc:0.1 | lr:7.26301097020845e-05, weight decay:2.661909869045578e-05
# val acc:0.09 | lr:0.0001632105010784518, weight decay:1.1561807936453578e-05
# val acc:0.1 | lr:3.4703996876735395e-06, weight decay:6.520143183131123e-06
# val acc:0.08 | lr:2.2936182357156944e-05, weight decay:5.878972106192358e-08
# val acc:0.08 | lr:5.36948256828423e-06, weight decay:9.977106572669364e-08
# val acc:0.73 | lr:0.004391679008226439, weight decay:3.8738920489273345e-07
# val acc:0.74 | lr:0.008064926306362902, weight decay:1.4713538911512297e-05
# val acc:0.17 | lr:1.0436204477357093e-06, weight decay:6.298752240116184e-07
# val acc:0.27 | lr:0.0006191300499855394, weight decay:1.6462799698149112e-06
# val acc:0.16 | lr:5.8009278891344975e-06, weight decay:1.610608698737666e-08
# val acc:0.63 | lr:0.0023569223933046415, weight decay:1.983862759655719e-06
# val acc:0.13 | lr:8.430295572636832e-06, weight decay:2.0046930624178283e-08
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.74) | lr:0.008064926306362902, weight decay:1.4713538911512297e-05
# Best-2(val acc:0.73) | lr:0.004391679008226439, weight decay:3.8738920489273345e-07
# Best-3(val acc:0.72) | lr:0.008085959771571434, weight decay:5.7566367206931485e-06
# Best-4(val acc:0.7) | lr:0.004639939561069104, weight decay:8.406673302506419e-07
# Best-5(val acc:0.63) | lr:0.0023569223933046415, weight decay:1.983862759655719e-06
# Best-6(val acc:0.55) | lr:0.001757776983822533, weight decay:3.036570407512711e-06
# Best-7(val acc:0.5) | lr:0.0018829571269024172, weight decay:1.0954389378122464e-08
# Best-8(val acc:0.4) | lr:0.001462524294862965, weight decay:3.357565594631702e-07
# Best-9(val acc:0.39) | lr:0.0007267081883997702, weight decay:2.920232423960345e-08
# Best-10(val acc:0.33) | lr:0.0009385721914522465, weight decay:6.080375215630573e-07
# Best-11(val acc:0.27) | lr:0.0006191300499855394, weight decay:1.6462799698149112e-06
# Best-12(val acc:0.17) | lr:1.8726502543195473e-05, weight decay:1.7385656070212144e-06
# Best-13(val acc:0.17) | lr:0.00045853837031889483, weight decay:2.218008472955756e-08
# Best-14(val acc:0.17) | lr:1.0436204477357093e-06, weight decay:6.298752240116184e-07
# Best-15(val acc:0.16) | lr:5.8009278891344975e-06, weight decay:1.610608698737666e-08
# Best-16(val acc:0.13) | lr:8.430295572636832e-06, weight decay:2.0046930624178283e-08
# Best-17(val acc:0.12) | lr:1.881862223921729e-05, weight decay:1.3758169094063597e-07
# Best-18(val acc:0.11) | lr:1.1066799823180722e-06, weight decay:5.4864843026001385e-05
# Best-19(val acc:0.11) | lr:1.4767610715040775e-06, weight decay:8.486760124207892e-05
# Best-20(val acc:0.1) | lr:1.7614813428783584e-05, weight decay:5.7747469452300216e-08
# weight decay min: -3 , weight decay max: -2 , lr min: -7 , lr max: -4
# val acc:0.09 | lr:1.4244994409388276e-05, weight decay:0.005294748472370591
# val acc:0.09 | lr:6.33177714165998e-05, weight decay:0.004864849482638103
# val acc:0.08 | lr:1.8923712874456373e-05, weight decay:0.0022708785090329903
# val acc:0.07 | lr:3.816465662107329e-06, weight decay:0.0013714936935167526
# val acc:0.14 | lr:2.010448692661571e-05, weight decay:0.005151916502874003
# val acc:0.11 | lr:2.637858016854783e-06, weight decay:0.006038731738876456
# val acc:0.08 | lr:2.326029434694665e-05, weight decay:0.006818057940108593
# val acc:0.2 | lr:2.633573174246991e-07, weight decay:0.0018572844101979466
# val acc:0.1 | lr:1.1868822326874154e-07, weight decay:0.0010050740963836189
# val acc:0.11 | lr:2.3189406532389256e-05, weight decay:0.0012962764399000006
# val acc:0.18 | lr:1.000669083838447e-07, weight decay:0.007246409515378307
# val acc:0.14 | lr:3.731094481907276e-05, weight decay:0.0031279951918375547
# val acc:0.14 | lr:5.176698224066794e-05, weight decay:0.008753334660657714
# val acc:0.09 | lr:2.9705902669633587e-05, weight decay:0.003418408914559669
# val acc:0.03 | lr:2.466988386767795e-06, weight decay:0.001767526881888509
# val acc:0.1 | lr:9.499029535618856e-07, weight decay:0.0028902459658109495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-180-13bfc301745d> in <module>
#      19         # ================================================
#      20
# ---> 21         val_acc_list, train_acc_list = __train(lr, weight_decay)
#      22         print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
#      23         # key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
#
# <ipython-input-164-2680f66e8298> in __train(lr, weight_decay, epocs)
#       5                       epochs=epocs, mini_batch_size=100,
#       6                       optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
# ----> 7     trainer.train()
#       8
#       9     return trainer.test_acc_list, trainer.train_acc_list
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\trainer.py in train(self)
#      69     def train(self):
#      70         for i in range(self.max_iter):
# ---> 71             self.train_step()
#      72
#      73         test_acc = self.network.accuracy(self.x_test, self.t_test)
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\trainer.py in train_step(self)
#      59                 x_test_sample, t_test_sample = self.x_test[:t], self.t_test[:t]
#      60
# ---> 61             train_acc = self.network.accuracy(x_train_sample, t_train_sample)
#      62             test_acc = self.network.accuracy(x_test_sample, t_test_sample)
#      63             self.train_acc_list.append(train_acc)
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\multi_layer_net.py in accuracy(self, x, t)
#      95
#      96     def accuracy(self, x, t):
# ---> 97         y = self.predict(x)
#      98         y = np.argmax(y, axis=1)
#      99         if t.ndim != 1 : t = np.argmax(t, axis=1)
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\multi_layer_net.py in predict(self, x)
#      69     def predict(self, x):
#      70         for layer in self.layers.values():
# ---> 71             x = layer.forward(x)
#      72
#      73         return x
#
# c:\Users\thyoo\Intelligent-system-design\deep-learning-from-scratch-master\common\layers.py in forward(self, x)
#      55         self.x = x
#      56
# ---> 57         out = np.dot(self.x, self.W) + self.b
#      58
#      59         return out
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
max(weight_decay_bests)
# Out:
# 0.009265894760845671
