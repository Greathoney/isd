# %%
import warnings

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.exceptions import ConvergenceWarning
from sklearn.neural_network import MLPClassifier

# %%
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
# # Load data from https://www.openml.org/d/554
# X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
# X = X / 255.

# Load data from https://www.openml.org/d/40996
X, y = fetch_openml('FASHION-MNIST', version=1, return_X_y=True)
X = X / 255.

# %%
# rescale the data, use the traditional train/test split
X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
mlp = MLPClassifier(hidden_layer_sizes=(50,), max_iter=10, alpha=1e-4,
                    solver='sgd', verbose=10, random_state=1,
                    learning_rate_init=.1)

# %%
# this example won't converge because of CI's time constraints, so we catch the
# warning and are ignore it here
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=ConvergenceWarning,
                            module="sklearn")
    mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.53238440
# Iteration 2, loss = 0.39300993
# Iteration 3, loss = 0.35940922
# Iteration 4, loss = 0.34054618
# Iteration 5, loss = 0.32284530
# Iteration 6, loss = 0.31124182
# Iteration 7, loss = 0.30183898
# Iteration 8, loss = 0.29540012
# Iteration 9, loss = 0.28711181
# Iteration 10, loss = 0.27971370

# %%
print("Training set score: %f" % mlp.score(X_train, y_train))
print("Test set score: %f" % mlp.score(X_test, y_test))
# Out:
# Training set score: 0.903200
# Test set score: 0.866500

# %%
fig, axes = plt.subplots(4, 4)
# use global min / max to ensure all weights are shown on the same scale
vmin, vmax = mlp.coefs_[0].min(), mlp.coefs_[0].max()
for coef, ax in zip(mlp.coefs_[0].T, axes.ravel()):
    ax.matshow(coef.reshape(28, 28), cmap=plt.cm.gray, vmin=.5 * vmin,
               vmax=.5 * vmax)
    ax.set_xticks(())
    ax.set_yticks(())

plt.show()

# %%
max_test_score = 0
maxScore_layer_size = 0

for layer_size in range(1, 100):
    print("\n------------------- hidden layer size = %d ------------------------" % layer_size)
    mlp = MLPClassifier(hidden_layer_sizes=(layer_size,), max_iter=10, alpha=1e-4,
                    solver='sgd', verbose=10, random_state=1,
                    learning_rate_init=.1)

    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning,
                                module="sklearn")
        mlp.fit(X_train, y_train)

    print("Training set score: %f" % mlp.score(X_train, y_train))

    test_score = mlp.score(X_test, y_test)
    print("Test set score: %f" % test_score)

    if max_test_score < test_score:
        max_test_score = test_score
        maXScore_layer_size = layer_size

    fig, axes = plt.subplots(4, 4)

    vmin, vmax = mlp.coefs_[0].min(), mlp.coefs_[0].max()
    for coef, ax in zip(mlp.coefs_[0].T, axes.ravel()):
        ax.matshow(coef.reshape(28, 28), cmap=plt.cm.gray, vmin=.5 * vmin,
                vmax=.5 * vmax)
        ax.set_xticks(())
        ax.set_yticks(())

    plt.show()
# Out:
# ------------------- hidden layer size = 1 ------------------------
# Iteration 1, loss = 1.57428547
# Iteration 2, loss = 1.37169935
# Iteration 3, loss = 1.40022282
# Iteration 4, loss = 1.39588254
# Iteration 5, loss = 1.40766110
# Iteration 6, loss = 1.44046880
# Iteration 7, loss = 1.36341420
# Iteration 8, loss = 1.65920202
# Iteration 9, loss = 1.32983542
# Iteration 10, loss = 1.41785981
# Training set score: 0.390283
# Test set score: 0.387200
# ------------------- hidden layer size = 2 ------------------------
# Iteration 1, loss = 1.70416540
# Iteration 2, loss = 1.50954404
# Iteration 3, loss = 1.54366265
# Iteration 4, loss = 1.73499510
# Iteration 5, loss = 1.67658629
# Iteration 6, loss = 1.66464415
# Iteration 7, loss = 1.52938939
# Iteration 8, loss = 1.77066344
# Iteration 9, loss = 1.72563651
# Iteration 10, loss = 1.57479288
# Training set score: 0.387800
# Test set score: 0.377600
# ------------------- hidden layer size = 3 ------------------------
# Iteration 1, loss = 0.83574804
# Iteration 2, loss = 0.68005584
# Iteration 3, loss = 0.65633386
# Iteration 4, loss = 0.63964035
# Iteration 5, loss = 0.62930407
# Iteration 6, loss = 0.62398072
# Iteration 7, loss = 0.61792720
# Iteration 8, loss = 0.61238618
# Iteration 9, loss = 0.61644507
# Iteration 10, loss = 0.34718190
# Training set score: 0.874483
# Test set score: 0.846500
# ------------------- hidden layer size = 19 ------------------------
# Iteration 1, loss = 0.61099027
# Iteration 2, loss = 0.43544868
# Iteration 3, loss = 0.41100895
# Iteration 4, loss = 0.39533221
# Iteration 5, loss = 0.38410148
# Iteration 6, loss = 0.37950274
# Iteration 7, loss = 0.37137108
# Iteration 8, loss = 0.36620574
# Iteration 9, loss = 0.36302937
# Iteration 10, loss = 0.36102197
# Training set score: 0.877033
# Test set score: 0.849000
# ------------------- hidden layer size = 20 ------------------------
# Iteration 1, loss = 0.59560119
# Iteration 2, loss = 0.42702359
# Iteration 3, loss = 0.40173268
# Iteration 4, loss = 0.38593797
# Iteration 5, loss = 0.37546334
# Iteration 6, loss = 0.36561242
# Iteration 7, loss = 0.36028666
# Iteration 8, loss = 0.35675281
# Iteration 9, loss = 0.35138370
# Iteration 10, loss = 0.34840489
# Training set score: 0.870050
# Test set score: 0.841800
# ------------------- hidden layer size = 21 ------------------------
# Iteration 1, loss = 0.59773316
# Iteration 2, loss = 0.43167367
# Iteration 3, loss = 0.40649750
# Iteration 4, loss = 0.39421540
# Iteration 5, loss = 0.38150665
# Iteration 6, loss = 0.37382050
# Iteration 7, loss = 0.36702192
# Iteration 8, loss = 0.36031957
# Iteration 9, loss = 0.35606165
# Iteration 10, loss = 0.34935587
# Training set score: 0.869667
# Test set score: 0.844600
# ------------------- hidden layer size = 22 ------------------------
# Iteration 1, loss = 0.58356324
# Iteration 2, loss = 0.42048608
# Iteration 3, loss = 0.39055132
# Iteration 4, loss = 0.37463268
# Iteration 5, loss = 0.36176971
# Iteration 6, loss = 0.35020384
# Iteration 7, loss = 0.34554534
# Iteration 8, loss = 0.33941525
# Iteration 9, loss = 0.33330585
# Iteration 10, loss = 0.32811926
# Training set score: 0.883367
# Test set score: 0.853400
# ------------------- hidden layer size = 23 ------------------------
# Iteration 1, loss = 0.57705355
# Iteration 2, loss = 0.41888705
# Iteration 3, loss = 0.39347512
# C:\Users\thyoo\anaconda3\envs\isd_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:619: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Training set score: 0.855533
# Test set score: 0.837100
# ------------------- hidden layer size = 24 ------------------------
# C:\Users\thyoo\anaconda3\envs\isd_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:619: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e01cb9b89d1b> in <module>
#      13         mlp.fit(X_train, y_train)
#      14
# ---> 15     print("Training set score: %f" % mlp.score(X_train, y_train))
#      16
#      17     test_score = mlp.score(X_test, y_test)
#
# ~\anaconda3\envs\isd_env\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     498         """
#     499         from .metrics import accuracy_score
# --> 500         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     501
#     502     def _more_tags(self):
#
# ~\anaconda3\envs\isd_env\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\isd_env\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     208         score = y_true == y_pred
#     209
# --> 210     return _weighted_sum(score, sample_weight, normalize)
#     211
#     212
#
# ~\anaconda3\envs\isd_env\lib\site-packages\sklearn\metrics\_classification.py in _weighted_sum(sample_score, sample_weight, normalize)
#     131 def _weighted_sum(sample_score, sample_weight, normalize=False):
#     132     if normalize:
# --> 133         return np.average(sample_score, weights=sample_weight)
#     134     elif sample_weight is not None:
#     135         return np.dot(sample_score, sample_weight)
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\anaconda3\envs\isd_env\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     378
#     379     if weights is None:
# --> 380         avg = a.mean(axis)
#     381         scl = avg.dtype.type(a.size/avg.size)
#     382     else:
#
# ~\anaconda3\envs\isd_env\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     176             is_float16_result = True
#     177
# --> 178     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     179     if isinstance(ret, mu.ndarray):
#     180         ret = um.true_divide(
#
# KeyboardInterrupt:
